# %% [markdown]
# <a href="https://colab.research.google.com/github/kwanqing/GoogleColab/blob/main/ZipDigits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import date
from google.colab import drive
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2023-08-24

# %%
df = pd.read_csv('/content/ZipDigits.info')
df.head()
# Out:
#                        Normalized handwritten digits  \
# 0  scanned from envelopes by the U.S. Postal Serv...
# 1  scanned digits are binary and of different siz...
# 2  images  here have been deslanted and size norm...
# 3         in 16 x 16 grayscale images (Le Cun et al.
# 4                  The data are in two gzipped files
#
#                           automatically
# 0                                   NaN
# 1                                   NaN
# 2                             resulting
# 3                                1990).
# 4   and each line consists of the digit

# %%
df1 = pd.read_csv('/content/ZipDigits.test')
df1.head()
# Out:
#   9.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.9480 -0.5610 0.1480 0.3840 0.9040 0.2900 -0.7820 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.7480 0.5880 1.0000 1.0000 0.9910 0.9150 1.0000 0.9310 -0.4760 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.7870 0.7940 1.0000 0.7270 -0.1780 -0.6930 -0.7860 -0.6240 0.8340 0.7560 -0.8220 -1.0000 -1.0000 -1.0000 -1.0000 -0.9220 0.8100 1.0000 0.0100 -0.9280 -1.0000 -1.0000 -1.0000 -1.0000 -0.3900 1.0000 0.2710 -1.0000 -1.0000 -1.0000 -1.0000 0.0120 1.0000 0.2480 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.4020 0.3260 1.0000 0.8010 -0.9980 -1.0000 -1.0000 -0.9810 0.6450 1.0000 -0.6870 -1.0000 -1.0000 -1.0000 -1.0000 -0.7920 0.9760 1.0000 1.0000 0.4130 -0.9760 -1.0000 -1.0000 -0.9930 0.8340 0.8970 -0.9510 -1.0000 -1.0000 -1.0000 -0.8310 0.1400 1.0000 1.0000 0.3020 -0.8890 -1.0000 -1.0000 -1.0000 -1.0000 0.3560 0.7940 -0.8360 -1.0000 -0.4450 0.0740 0.8330 1.0000 1.0000 0.6960 -0.8810 -1.0000 -1.0000 -1.0000 -1.0000 -1.
# ...

# %%
df2 = pd.read_csv('/content/ZipDigits.train')
df2.head()
# Out:
#   6.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.6310 0.8620 -0.1670 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.9920 0.2970 1.0000 0.3070 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.4100 1.0000 0.9860 -0.5650 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.6830 0.8250 1.0000 0.5620 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.9380 0.5400 1.0000 0.7780 -0.7150 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 0.1000 1.0000 0.9220 -0.4390 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.2570 0.9500 1.0000 -0.1620 -1.0000 -1.0000 -1.0000 -0.9870 -0.7140 -0.8320 -1.0000 -1.0000 -1.0000 -1.0000 -1.0000 -0.7970 0.9090 1.0000 0.3000 -0.9610 -1.0000 -1.0000 -0.5500 0.4850 0.9960 0.8670 0.0920 -1.00
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/kwanqing/CMPE-257/blob/main/synthetic_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("synthetic_dataset.csv")
df.head()
# Out:
#          x1        x2  y
# 0 -4.641770  5.558556  1
# 1  7.139793  6.571105  1
# 2  4.127969 -9.024912 -1
# 3  0.081377  3.861381  1
# 4 -1.253937  8.009625  1

# %%
df.insert(3, "x0", 1)
df.head()
# Out:
#          x1        x2  y  x0
# 0 -4.641770  5.558556  1   1
# 1  7.139793  6.571105  1   1
# 2  4.127969 -9.024912 -1   1
# 3  0.081377  3.861381  1   1
# 4 -1.253937  8.009625  1   1

# %%
x1 = df.loc[:,"x1"]
x2 = df.loc[:,"x2"]
y = df.loc[:,"y"]
x0 = df.loc[:,"x0"]

# %%
w = [0, 0, 0]
vector2 = np.array([x0, x1, x2])

# %%
def sign(x):
  if x >= 0:
    return 1
  else:
    return -1

# %%
def get_sign(x, w):
  # dot_product = x[0]*w[0] + x[1]*w[1] + x[2]*w[2]
  return sign(dot_product)

# %%
dot_product = np.dot(w, vector2)
sign_output = []
for i in range (len(dot_product)):
  sign_output.append(sign(dot_product[i]))

# %%
misclassified_example = []
for i in range (len(y)):
  if sign_output[i] != y[i]:
    print("yes")
  else:
    print("no")
# Out:
# no
# no
# yes
# no
# no
# yes
# yes
# no
# no
# no
# yes
# yes
# yes
# no
# yes
# no
# yes
# no
# yes
# yes
# no
# no
# no
# no
# yes
# yes
# yes
# no
# yes
# no
# no
# yes
# yes
# no
# yes
# yes
# no
# no
# yes
# no
# no
# no
# no
# yes
# no
# no
# no
# yes
# no
# no
